-- %%
SELECT ALL r.NAME , f.LASTNAME , f.FIRSTNAME , f.FAMREGNO , f.BIRTHDATE , f.PROFESSIONID , f.jobid,f.ORGNAME ,f.NOTE ,f.PHONE 
FROM 
HRMS_PROD.HREMPFAMILY f, HRMS_PROD.SIRELATIVE r
WHERE EMPID in(
6366,
6117,
15448,
25711,
6369,
11405
)
AND f.RELATIVEID = r.RELATIVEID
